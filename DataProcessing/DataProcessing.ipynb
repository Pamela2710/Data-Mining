# %% [markdown]
# <a href="https://colab.research.google.com/github/Pamela2710/Data-Mining/blob/main/DataProcessing/DataProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/Pamela2710/Data-Mining/main/DataProcessing/features_completas.csv', encoding='latin-1')
df
# Out:
#      Media tiempo  Desviacion estandar tiempo  Varianza tiempo  \
# 0        0.099520                    0.245902         0.108890
# 1        0.085819                    0.876726         0.796870
# 2        0.077419                    0.231336         0.099950
# 3        0.102426                    0.291445         0.138865
# 4        0.091737                    0.428982         0.247991
# ..            ...                         ...              ...
# 685      0.101867                    0.214477         0.089995
# 686      0.086898                    0.680620         0.520007
# 687      0.077123                    0.548769         0.365809
# 688      0.079244                    0.720172         0.571271
# 689      0.087387                    0.129870         0.046375
#
#      Entropia tiempo  kurtosis tiempo  MSE tiempo  \
# 0                  0         0.013447    0.907095
# 1                  0         0.050793    0.351758
# 2                  0         0.015484    0.882481
# ...
